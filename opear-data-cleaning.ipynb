# %% [markdown]
# # Perform the following operations using Python on the Air quality and Heart Diseases data sets
# a. Data cleaning
# b. Data integratio
# c. Data transformatin
# d. Error correctng
# e. Data model builg

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random as rd

# %%
df=pd.read_csv("heartdisease.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  num
# 0        3  0    6    0
# 1        2  3    3    2
# ...

# %%
ds=pd.read_csv("AirQualityUCI.csv")
ds
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  Wind  \
# 0     10-03-2004  18:00:00     2.6         1360       150  11.9
# 1     10-03-2004  19:00:00     2.0         1292       112   9.4
# 2     10-03-2004  20:00:00     2.2         1402        88   9.0
# 3     10-03-2004  21:00:00     2.2         1376        80   9.2
# 4     10-03-2004  22:00:00     1.6         1272        51   6.5
# ...          ...       ...     ...          ...       ...   ...
# 9352  04-04-2005  10:00:00     3.1         1314      -200  13.5
# 9353  04-04-2005  11:00:00     2.4         1163      -200  11.4
# 9354  04-04-2005  12:00:00     2.4         1142      -200  12.4
# 9355  04-04-2005  13:00:00     2.1         1003      -200   9.5
# 9356  04-04-2005  14:00:00     2.2         1071      -200  11.9
#
#       PT08.S2(NMHC)  Solor.R  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  Ozone  \
# 0              1046      166          1056      113          1692   1268
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  num       303 non-null    int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 33.3+ KB

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   int64
#  4   NMHC(GT)       9357 non-null   int64
#  5   Wind           9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   int64
#  7   Solor.R        9357 non-null   int64
#  8   PT08.S3(NOx)   9357 non-null   int64
#  9   NO2(GT)        9357 non-null   int64
#  10  PT08.S4(NO2)   9357 non-null   int64
#  11  Ozone          9357 non-null   int64
#  12  Temp           9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
ds.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# Wind             0
# PT08.S2(NMHC)    0
# Solor.R          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# Ozone            0
# Temp             0
# RH               0
# AH               0
# dtype: int64

# %%
df.dropna()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  num
# 0        3  0    6    0
# 1        2  3    3    2
# ...

# %%
ds1=ds.loc[111:999,['Date','Time','Wind','Ozone']]
ds1
# Out:
#            Date      Time  Wind  Ozone
# 111  15-03-2004  09:00:00  36.7   2184
# 112  15-03-2004  10:00:00  26.6   1973
# 113  15-03-2004  11:00:00  20.1   1798
# 114  15-03-2004  12:00:00  14.1   1522
# 115  15-03-2004  13:00:00  14.9   1404
# ..          ...       ...   ...    ...
# 995  21-04-2004  05:00:00   3.7    779
# 996  21-04-2004  06:00:00   8.7   1009
# 997  21-04-2004  07:00:00  27.0   1595
# 998  21-04-2004  08:00:00  40.3   1940
# 999  21-04-2004  09:00:00  20.0   1628
#
# [889 rows x 4 columns]

# %%
ds2=ds.iloc[[1,3,5,2,4,8,9,7,10,11,12]]
ds2
# Out:
#           Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  Wind  PT08.S2(NMHC)  \
# 1   10-03-2004  19:00:00     2.0         1292       112   9.4            955
# 3   10-03-2004  21:00:00     2.2         1376        80   9.2            948
# 5   10-03-2004  23:00:00     1.2         1197        38   4.7            750
# 2   10-03-2004  20:00:00     2.2         1402        88   9.0            939
# 4   10-03-2004  22:00:00     1.6         1272        51   6.5            836
# 8   11-03-2004  02:00:00     0.9         1094        24   2.3            609
# 9   11-03-2004  03:00:00     0.6         1010        19   1.7            561
# 7   11-03-2004  01:00:00     1.0         1136        31   3.3            672
# 10  11-03-2004  04:00:00  -200.0         1011        14   1.3            527
# 11  11-03-2004  05:00:00     0.7         1066         8   1.1            512
# 12  11-03-2004  06:00:00     0.7         1052        16   1.6            553
#
# ...

# %%
ds_integration=pd.concat([ds1,ds2])
ds_integration
# Out:
#            Date      Time  Wind  Ozone  CO(GT)  PT08.S1(CO)  NMHC(GT)  \
# 111  15-03-2004  09:00:00  36.7   2184     NaN          NaN       NaN
# 112  15-03-2004  10:00:00  26.6   1973     NaN          NaN       NaN
# 113  15-03-2004  11:00:00  20.1   1798     NaN          NaN       NaN
# 114  15-03-2004  12:00:00  14.1   1522     NaN          NaN       NaN
# 115  15-03-2004  13:00:00  14.9   1404     NaN          NaN       NaN
# ..          ...       ...   ...    ...     ...          ...       ...
# 9    11-03-2004  03:00:00   1.7    501     0.6       1010.0      19.0
# 7    11-03-2004  01:00:00   3.3    730     1.0       1136.0      31.0
# 10   11-03-2004  04:00:00   1.3    445  -200.0       1011.0      14.0
# 11   11-03-2004  05:00:00   1.1    422     0.7       1066.0       8.0
# 12   11-03-2004  06:00:00   1.6    472     0.7       1052.0      16.0
#
#      PT08.S2(NMHC)  Solor.R  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  Temp    RH  \
# ...

# %%
ds_integration.transpose()
# Out:
#                       111         112         113         114         115  \
# Date           15-03-2004  15-03-2004  15-03-2004  15-03-2004  15-03-2004
# Time             09:00:00    10:00:00    11:00:00    12:00:00    13:00:00
# Wind                 36.7        26.6        20.1        14.1        14.9
# Ozone                2184        1973        1798        1522        1404
# CO(GT)                NaN         NaN         NaN         NaN         NaN
# PT08.S1(CO)           NaN         NaN         NaN         NaN         NaN
# NMHC(GT)              NaN         NaN         NaN         NaN         NaN
# PT08.S2(NMHC)         NaN         NaN         NaN         NaN         NaN
# Solor.R               NaN         NaN         NaN         NaN         NaN
# PT08.S3(NOx)          NaN         NaN         NaN         NaN         NaN
# NO2(GT)               NaN         NaN         NaN         NaN         NaN
# PT08.S4(NO2)          NaN         NaN         NaN         NaN         NaN
# ...

# %%
ds.drop(columns="Ozone")
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  Wind  \
# 0     10-03-2004  18:00:00     2.6         1360       150  11.9
# 1     10-03-2004  19:00:00     2.0         1292       112   9.4
# 2     10-03-2004  20:00:00     2.2         1402        88   9.0
# 3     10-03-2004  21:00:00     2.2         1376        80   9.2
# 4     10-03-2004  22:00:00     1.6         1272        51   6.5
# ...          ...       ...     ...          ...       ...   ...
# 9352  04-04-2005  10:00:00     3.1         1314      -200  13.5
# 9353  04-04-2005  11:00:00     2.4         1163      -200  11.4
# 9354  04-04-2005  12:00:00     2.4         1142      -200  12.4
# 9355  04-04-2005  13:00:00     2.1         1003      -200   9.5
# 9356  04-04-2005  14:00:00     2.2         1071      -200  11.9
#
#       PT08.S2(NMHC)  Solor.R  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  Temp    RH  \
# 0              1046      166          1056      113          1692  13.6  48.9
# ...

# %%
ds2.drop(1)
# Out:
#           Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  Wind  PT08.S2(NMHC)  \
# 3   10-03-2004  21:00:00     2.2         1376        80   9.2            948
# 5   10-03-2004  23:00:00     1.2         1197        38   4.7            750
# 2   10-03-2004  20:00:00     2.2         1402        88   9.0            939
# 4   10-03-2004  22:00:00     1.6         1272        51   6.5            836
# 8   11-03-2004  02:00:00     0.9         1094        24   2.3            609
# 9   11-03-2004  03:00:00     0.6         1010        19   1.7            561
# 7   11-03-2004  01:00:00     1.0         1136        31   3.3            672
# 10  11-03-2004  04:00:00  -200.0         1011        14   1.3            527
# 11  11-03-2004  05:00:00     0.7         1066         8   1.1            512
# 12  11-03-2004  06:00:00     0.7         1052        16   1.6            553
#
#     Solor.R  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  Ozone  Temp    RH      AH
# ...

# %%
ds.melt()
# Out:
#        variable       value
# 0          Date  10-03-2004
# 1          Date  10-03-2004
# 2          Date  10-03-2004
# 3          Date  10-03-2004
# 4          Date  10-03-2004
# ...         ...         ...
# 140350       AH      0.7568
# 140351       AH      0.7119
# 140352       AH      0.6406
# 140353       AH      0.5139
# 140354       AH      0.5028
#
# [140355 rows x 2 columns]

# %%
ds_merged=pd.concat([ds,df])
ds_merged
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  Wind  PT08.S2(NMHC)  \
# 0    10-03-2004  18:00:00     2.6       1360.0     150.0  11.9         1046.0
# 1    10-03-2004  19:00:00     2.0       1292.0     112.0   9.4          955.0
# 2    10-03-2004  20:00:00     2.2       1402.0      88.0   9.0          939.0
# 3    10-03-2004  21:00:00     2.2       1376.0      80.0   9.2          948.0
# 4    10-03-2004  22:00:00     1.6       1272.0      51.0   6.5          836.0
# ..          ...       ...     ...          ...       ...   ...            ...
# 298         NaN       NaN     NaN          NaN       NaN   NaN            NaN
# 299         NaN       NaN     NaN          NaN       NaN   NaN            NaN
# 300         NaN       NaN     NaN          NaN       NaN   NaN            NaN
# 301         NaN       NaN     NaN          NaN       NaN   NaN            NaN
# 302         NaN       NaN     NaN          NaN       NaN   NaN            NaN
#
# ...

# %%
df['ca'].unique()
# Out:
# array(['0', '3', '2', '1', '?'], dtype=object)

# %%
df.ca.value_counts()
# Out:
# ca
# 0    176
# 1     65
# 2     38
# 3     20
# ?      4
# Name: count, dtype: int64

# %%
from sklearn import linear_model,metrics
X=df[["age"]]
Y=df[["cp"]]
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
len(X_train)
# Out:
# 242

# %%
len(X_test)
# Out:
# 61

# %%
ds.shape
# Out:
# (9357, 15)

# %%
reg=linear_model.LinearRegression()
print(X_train)
# Out:
#      age
# 62    58
# 127   54
# 111   56
# 287   58
# 108   61
# ..   ...
# 203   64
# 255   42
# 72    62
# 235   54
# 37    57
#
# [242 rows x 1 columns]

# %%
model=reg.fit(X_train,Y_train)
r_sq=reg.score(X_train,Y_train)
print("determination coefficient:" , r_sq)
# Out:
# determination coefficient: 0.008598734317381118

# %%
print('slope:',model.coef_)
# Out:
# slope: [[0.00960843]]

# %%
Y_pred=model.predict(X_test)
print('predicted response:',Y_pred,sep='\n')
# Out:
# predicted response:
# [[3.08435318]
#  [3.32456398]
#  [3.23808809]
#  [3.28613025]
#  [3.24769652]
#  [3.06513631]
#  [3.07474474]
#  [3.29573868]
#  [3.26691338]
#  [3.28613025]
#  [3.29573868]
#  [3.26691338]
#  [3.21887122]
#  [3.30534711]
#  [3.19965436]
#  [3.03631102]
#  [3.19004593]
#  [3.06513631]
#  [3.13239534]
#  [3.19004593]
#  [3.20926279]
#  [3.21887122]
#  [3.29573868]
#  [3.21887122]
#  [3.16122063]
#  [3.13239534]
#  [3.16122063]
#  [3.10357004]
#  [3.30534711]
#  [3.19965436]
#  [3.22847966]
#  [3.20926279]
#  [3.05552788]
#  [3.16122063]
#  [3.40143143]
#  [3.29573868]
#  [3.17082906]
#  [3.10357004]
#  [3.33417241]
#  [3.17082906]
#  [3.21887122]
#  [3.21887122]
#  [3.00748572]
#  [3.1804375 ]
#  [3.23808809]
#  [3.07474474]
#  [3.20926279]
#  [3.06513631]
#  [3.00748572]
#  [3.17082906]
#  [3.13239534]
#  [3.19004593]
#  [3.32456398]
#  [3.16122063]
#  [3.13239534]
#  [3.1804375 ]
#  [3.27652182]
#  [3.20926279]
#  [3.21887122]
#  [3.1804375 ]
#  [3.25730495]]

# %%
plt.scatter(X_train,Y_train,color='black')
plt.plot(X_train,reg.predict(X_train),color='blue',linewidth=3)
plt.title("age vs cp")
plt.xlabel("age")
plt.xlabel("cp")
plt.show()

# %%
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,reg.predict(X_train),color='black',linewidth=3)
plt.title("age vs ca")
plt.xlabel("age")
plt.xlabel("ca")
plt.show()
